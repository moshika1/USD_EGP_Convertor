# %%
import requests 
from bs4 import BeautifulSoup

# %%
url = 'https://www.exchangerates.org.uk/Dollars-to-Egyptian-Pounds-currency-conversion-page.html'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text , 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta charset="utf-8"/>
# <title>Dollar to Egyptian Pound Exchange Rate Today, Live 1 USD to EGP = 15.7155 (Convert Dollars to Egyptian Pounds)</title>
# <meta content="Compare the best Dollar Egyptian Pound exchange rate deals &amp; Dollars to Egyptian Pounds exchange today! Live Dollar to Egyptian Pound exchange rate comparison tables, charts and USD EGP history" name="description"/>
# <meta content="Dollars to Egyptian Pounds , USD EGP, 1 USD to EGP" name="keywords"/>
# <meta content="no-cache" http-equiv="cache-control"/>
# <script>
#   (function (i, s, o, g, r, a, m) {
#     i['GoogleAnalyticsObject'] = r;
#     i[r] = i[r] || function () {
#           (i[r].q = i[r].q || []).push(arguments)
#         }, i[r].l = 1 * new Date();
#     a = s.createElement(o),
#         m = s.getElementsByTagName(o)[0];
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta charset="utf-8"/>
#   <title>
#    Dollar to Egyptian Pound Exchange Rate Today, Live 1 USD to EGP = 15.7155 (Convert Dollars to Egyptian Pounds)
#   </title>
#   <meta content="Compare the best Dollar Egyptian Pound exchange rate deals &amp; Dollars to Egyptian Pounds exchange today! Live Dollar to Egyptian Pound exchange rate comparison tables, charts and USD EGP history" name="description"/>
#   <meta content="Dollars to Egyptian Pounds , USD EGP, 1 USD to EGP" name="keywords"/>
#   <meta content="no-cache" http-equiv="cache-control"/>
#   <script>
#    (function (i, s, o, g, r, a, m) {
#     i['GoogleAnalyticsObject'] = r;
#     i[r] = i[r] || function () {
#           (i[r].q = i[r].q || []).push(arguments)
#         }, i[r].l = 1 * new Date();
#     a = s.createElement(o),
# ...

# %%
convertor = soup.find('span', attrs={'id': 'shd2b;'})
convertor
# Out:
# <span id="shd2b;">15.7155</span>

# %%
convertor = float(convertor)
convertor
# Out:
# 15.7155

# %%
usd_amount = int(input('enter usd amount'))
usd_egp_convertor = usd_amount * convertor 
print(f'{usd_amount} Dollars equal {usd_egp_convertor} Egyptian Pounds')
# Out:
# 100 Dollars equal 1571.55 Egyptian Pounds
